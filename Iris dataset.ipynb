# %% [markdown]
# This notebook displays how to read and load the Iris dataset from the UCI Machine Learning repository.
#
# It further demonstrates univariate statistics and visualizations carried out on each species.

# %%
## importing the necessary packages

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pd.set_option("display.max_columns",100)

# %%
column_names = ["sepal length", "sepal width", "petal length", "petal width", "class"]

# %%
iris = pd.read_csv("http://mlr.cs.umass.edu/ml/machine-learning-databases/iris/iris.data", names = column_names)

# %%
## checking the dimension of the dataset

iris.shape
# Out:
# (150, 5)

# %%
## taking a peek at the first and last five rows

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
## checking the data type of each column

iris.dtypes
# Out:
# sepal length    float64
# sepal width     float64
# petal length    float64
# petal width     float64
# class            object
# dtype: object

# %%
## calculating univariate statistics on each column

# %%
iris.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
## calculating univariate statistics on each species

# %%
iris.pivot_table(index = "class", values = ["sepal length","sepal width","petal length","petal width"], aggfunc = "describe")
# Out:
#                 petal length                                                \
#                          25%   50%    75% count  max   mean  min       std
# class
# Iris-setosa              1.4  1.50  1.575  50.0  1.9  1.464  1.0  0.173511
# Iris-versicolor          4.0  4.35  4.600  50.0  5.1  4.260  3.0  0.469911
# Iris-virginica           5.1  5.55  5.875  50.0  6.9  5.552  4.5  0.551895
#
#                 petal width                                             \
#                         25%  50%  75% count  max   mean  min       std
# class
# Iris-setosa             0.2  0.2  0.3  50.0  0.6  0.244  0.1  0.107210
# Iris-versicolor         1.2  1.3  1.5  50.0  1.8  1.326  1.0  0.197753
# Iris-virginica          1.8  2.0  2.3  50.0  2.5  2.026  1.4  0.274650
#
#                 sepal length                                             \
#                          25%  50%  75% count  max   mean  min       std
# class
# Iris-setosa            4.800  5.0  5.2  50.0  5.8  5.006  4.3  0.352490
# Iris-versicolor        5.600  5.9  6.3  50.0  7.0  5.936  4.9  0.516171
# Iris-virginica         6.225  6.5  6.9  50.0  7.9  6.588  4.9  0.635880
#
#                 sepal width
#                         25%  50%    75% count  max   mean  min       std
# class
# Iris-setosa           3.125  3.4  3.675  50.0  4.4  3.418  2.3  0.381024
# Iris-versicolor       2.525  2.8  3.000  50.0  3.4  2.770  2.0  0.313798
# Iris-virginica        2.800  3.0  3.175  50.0  3.8  2.974  2.2  0.322497

# %%
## calculating the median of all the attributes(the robust measure) species wise

# %%
iris.pivot_table(index = "class", values = ["sepal length","sepal width","petal length","petal width"], aggfunc = "median")
# Out:
#                  petal length  petal width  sepal length  sepal width
# class
# Iris-setosa              1.50          0.2           5.0          3.4
# Iris-versicolor          4.35          1.3           5.9          2.8
# Iris-virginica           5.55          2.0           6.5          3.0

# %%
## calculating the mean of all the attributes species wise

# %%
iris.pivot_table(index = "class", values = ["sepal length","sepal width","petal length","petal width"], aggfunc = "mean")
# Out:
#                  petal length  petal width  sepal length  sepal width
# class
# Iris-setosa             1.464        0.244         5.006        3.418
# Iris-versicolor         4.260        1.326         5.936        2.770
# Iris-virginica          5.552        2.026         6.588        2.974

# %%
## looking the distribution of the attributes, namely sepal length, sepal width, petal length, and petal width

# %%
iris.plot.hist(alpha = 0.5, bins=20)

# %%
## refining the above plot

# %%
iris.hist(alpha = 0.5, bins=20,grid = False, figsize=(12,8),color = "r")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0821EFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0829F930>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0865DFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x08694990>]], dtype=object)

# %%
## looking at the distribution of the attributes with boxplots

# %%
iris.plot.box(figsize=(12,8))

# %%
## looking at the distribution of attributes species wise

# %%
iris["class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris_setosa = iris[iris["class"] == 'Iris-setosa']

# %%
iris_versicolor = iris[iris["class"] == 'Iris-versicolor']

# %%
iris_virginica = iris[iris["class"] == 'Iris-virginica']

# %%
iris_setosa.hist(grid = False,figsize=(9,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x088944F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0893E090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0897A350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x089B1170>]], dtype=object)

# %%
iris_versicolor.hist(grid = False,figsize=(9,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x086B9510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x08C92F10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x08CD8350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x08D06F30>]], dtype=object)

# %%
iris_virginica.hist(grid = False,figsize=(9,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x091610F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x090420B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0907F4F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x090AEF30>]], dtype=object)

# %%
## scatter matrix

# %%
sns.set()

sns.pairplot(iris, hue="class")
