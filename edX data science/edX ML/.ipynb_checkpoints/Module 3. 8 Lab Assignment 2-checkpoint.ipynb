# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# Look pretty...
matplotlib.style.use('ggplot')


#
# TODO: Load up the Seeds Dataset into a Dataframe
# It's located at 'Datasets/wheat.data'
# 
df = pd.read_csv(r"C:\Users\aaaaaaaa\Desktop\edX ML\Module 3\Module3\Datasets\wheat.data",index_col = 0)


#
# TODO: Create a 2d scatter plot that graphs the
# area and perimeter features
# 
plt.figure(figsize = (10,8))
plt.scatter(df.area, df.perimeter, marker = ".", color = "b", alpha = 0.7)


#
# TODO: Create a 2d scatter plot that graphs the
# groove and asymmetry features
# 
plt.figure(figsize = (10,8))
plt.scatter(df.groove, df.asymmetry, marker = ".", color = "b", alpha = 0.7)
#
# TODO: Create a 2d scatter plot that graphs the
# compactness and width features
# 
plt.figure(figsize = (10,8))
plt.scatter(df.compactness, df.width, marker = ".", color = "b", alpha = 0.7)



# BONUS TODO:
# After completing the above, go ahead and run your program
# Check out the results, and see what happens when you add
# in the optional display parameter marker with values of
# either '^', '.', or 'o'.


plt.show()
