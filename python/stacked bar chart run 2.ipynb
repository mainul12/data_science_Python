# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use("ggplot")
plt.bar(["A", "B", "C", "D"], [5, 10, 3, 2], label = "Men", width = 0.35)
plt.bar(["A", "B", "C", "D"], [29, 10, 5, 5], bottom=[5, 10, 3, 2], width = 0.35, label = "Women")
plt.legend()

# %%
plt.style.use("ggplot")
plt.bar(["1", "2", "3", "4"], [5, 10, 3, 29], width = 0.35)
# Out:
# <BarContainer object of 4 artists>
