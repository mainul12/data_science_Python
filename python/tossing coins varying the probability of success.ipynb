# %% [markdown]
# Kottemann: Chapter 6

# %%
from symbulate import *
# %matplotlib inline

# %%
#chance of heads is 50%

P = BoxModel([0, 1], size = 10, probs=[0.5, 0.5])
X = RV(P, sum)
X.sim(10000).plot()

# %%
#chance of heads is 25%

P = BoxModel([0, 1], size = 10, probs=[0.75, 0.25])
X = RV(P, sum)
X.sim(10000).plot()

# %%
#chance of heads is 10%

P = BoxModel([0, 1], size = 10, probs=[0.90, 0.10])
X = RV(P, sum)
X.sim(10000).plot()
